# %% [markdown]
# This notebook aims to demostrate the Poisson and ZI-Poisson simulators after refactoring. The code and structure of this notebook are mostly borrowed from Langtian's NB_scale_model branch.

# %%
from scdesigner.datasets import pancreas

example_sce = pancreas()

# %% [markdown]
# # refactored Poisson

# %%
from scdesigner.simulators import PoissonCopula

# %% [markdown]
# Here I generated a 2000 x 20 dataset of Poisson distributions, with Poisson's lambda parameter (beta in the code) generated from a 2000 x 2 matrix (signifying the observed covariate values) and a 2 x 20 matrix (signifying the ground truth parameters of the regression model).

# %%
import anndata
import numpy as np
import pandas as pd
from scipy.stats import poisson

n_sample, n_gene, n_feature1 = 2000, 20, 2
X1 = np.random.normal(size=(n_sample, n_feature1)) # covariates
ground_truth = np.random.normal(size=(n_feature1, n_gene)) # feature x gene
beta = np.exp(X1 @ ground_truth) # cell x gene

# generate samples
Y = poisson(beta).rvs()
obs = pd.DataFrame(X1, columns=[f"dim{j}" for j in range(n_feature1)]) # cell x feature
adata = anndata.AnnData(X=Y, obs=obs)
adata
# Out:
# AnnData object with n_obs × n_vars = 2000 × 20
#     obs: 'dim0', 'dim1'

# %%
formula = "~ dim0 + dim1 - 1"
poisson = PoissonCopula(formula)
poisson.fit(adata)
# Out:
# Epoch 112/500, Loss: 1.3741, Val Loss: 1.3536
# Estimating copula correlation: 100%|██████████| 2/2 [00:00<00:00, 22.17it/s]

# %%
print("Ground Truth beta:")
display(pd.DataFrame(ground_truth))
print("Estimated beta:")
display(poisson.parameters["marginal"]["mean"])
# Out:
# Ground Truth beta:
#          0         1         2         3         4         5         6   \
# 0 -0.830603  0.656957 -0.198403  2.231122  0.491121  0.150315  0.292499
# 1 -1.012377 -1.364568 -0.320556 -0.245301 -0.929073 -1.004499  0.066603
#
#          7         8         9         10        11        12        13  \
# 0  0.975406  0.361655  1.017241 -0.352158  2.755312 -0.782739 -0.407076
# 1  0.686679  0.888105 -0.861221 -0.714054 -0.291000 -0.906791 -1.014394
#
#          14        15        16        17        18        19
# 0  0.051976  1.057187  0.239356 -0.337252  0.036141  1.251893
# 1  0.179791  1.775800 -2.032434 -0.587728 -2.448057  0.104134
# Estimated beta:
#              0         1         2         3         4         5         6  \
# dim0 -0.830193  0.643490 -0.193614  2.230634  0.492995  0.120005  0.281121
# dim1 -1.005797 -1.376388 -0.344828 -0.242619 -0.918832 -1.013566  0.064130
#
#              7         8         9        10        11        12        13  \
# dim0  0.965224  0.398354  1.027165 -0.376901  2.766722 -0.784553 -0.402225
# dim1  0.664923  0.890837 -0.851559 -0.701014 -0.271106 -0.910988 -1.023696
#
#             14        15        16        17        18        19
# dim0  0.059475  1.054566  0.233732 -0.337474  0.035355  1.251190
# dim1  0.149370  1.771196 -2.031343 -0.569106 -2.447169  0.123364

# %% [markdown]
# # Bernoulli

# %%
from scipy.stats import bernoulli
from scipy.special import expit

n_sample, n_gene, n_feature1 = 2000, 20, 2
X1 = np.random.normal(size=(n_sample, n_feature1)) # covariates
ground_truth = np.random.normal(size=(n_feature1, n_gene)) # feature x gene
beta = expit(X1 @ ground_truth) # cell x gene


# generate samples
Y = bernoulli(beta).rvs()
obs = pd.DataFrame(X1, columns=[f"dim{j}" for j in range(n_feature1)]) # cell x feature
adata = anndata.AnnData(X=Y, obs=obs)

# %%
from scdesigner.simulators import BernoulliCopula
formula = "~ dim0 + dim1 - 1"
bsim = BernoulliCopula(formula)
bsim.fit(adata)
# Out:
# Epoch 339/500, Loss: 0.5557, Val Loss: 0.5637
# Estimating copula correlation: 100%|██████████| 2/2 [00:00<00:00, 37.59it/s]

# %%
print("Ground Truth:")
display(pd.DataFrame(ground_truth))
print("Estimated:")
display(bsim.parameters["marginal"]["mean"])
# Out:
# Ground Truth:
#          0         1         2         3         4         5         6   \
# 0  0.120822 -1.867902 -0.922217 -1.247241 -0.761936  1.141497 -0.022230
# 1  0.972776 -0.578010  1.128724  0.584409  0.717006 -0.559839  1.143145
#
#          7         8         9         10        11        12        13  \
# 0  0.256417 -1.127463 -1.082719 -0.980855 -2.101902  0.051548  0.002044
# 1  0.611842 -0.529631 -1.006605 -0.308540  1.632083 -0.296456  1.310496
#
#          14        15        16        17        18        19
# 0  2.442796 -1.483515  0.380695 -0.880889 -0.753385  1.006305
# 1  0.268166  0.035129  0.711554 -1.482683  0.008811  1.099123
# Estimated:
#              0         1         2         3        4         5         6  \
# dim0  0.112003 -1.658552 -0.979016 -1.206004 -0.89173  1.176987 -0.109032
# dim1  0.857778 -0.460501  1.234205  0.547326  0.86723 -0.561945  1.008466
#
#              7         8         9        10        11        12        13  \
# dim0  0.314086 -1.043487 -0.880065 -0.916936 -1.646434  0.083122 -0.004193
# dim1  0.615080 -0.470064 -0.865510 -0.353323  1.306295 -0.316928  1.264242
#
#             14        15        16        17        18        19
# dim0  1.816206 -1.413238  0.452893 -0.832209 -0.745058  0.976841
# dim1  0.147314 -0.016060  0.681111 -1.374789  0.053604  1.128001

# %% [markdown]
# # refactored ZI-Poisson

# %%
from scdesigner.simulators import ZeroInflatedPoissonCopula

# %% [markdown]
# I followed similar steps to generate a zero-inflated poisson distribution, allowing covariates for the zero inflation term.

# %%
from scipy.stats import poisson, bernoulli

n_sample, n_gene, n_feature1, n_feature2 = 2000, 20, 2, 3
X1 = np.random.normal(size=(n_sample, n_feature1)) # beta covariates
X2 = np.random.normal(size=(n_sample, n_feature2)) # zero-inflation covariates
gt_beta = np.random.normal(size=(n_feature1, n_gene))
gt_pi = np.random.normal(size=(n_feature2, n_gene))
beta = np.exp(X1 @ gt_beta)
pi = 1 / (1 + np.exp(-(X2 @ gt_pi)))

# generate samples
Y = poisson(beta).rvs() * bernoulli(1 - pi).rvs()
obs1 = pd.DataFrame(X1, columns=[f"beta_dim{j}" for j in range(n_feature1)])
obs2 = pd.DataFrame(X2, columns=[f"pi_dim{j}" for j in range(n_feature2)])
obs = pd.concat([obs1, obs2], axis=1)
adata = anndata.AnnData(X=Y, obs=obs)
adata
# Out:
# AnnData object with n_obs × n_vars = 2000 × 20
#     obs: 'beta_dim0', 'beta_dim1', 'pi_dim0', 'pi_dim1', 'pi_dim2'

# %%
formula = {"mean_formula": "~ beta_dim0 + beta_dim1 - 1",
           "zero_inflation_formula": "~ pi_dim0 + pi_dim1 + pi_dim2 - 1"}
zip = ZeroInflatedPoissonCopula(**formula)
zip.fit(adata)
# Out:
# Epoch 129/500, Loss: 1.0781, Val Loss: 1.0836
# Estimating copula correlation: 100%|██████████| 2/2 [00:00<00:00, 18.56it/s]

# %%
print("Ground Truth beta:")
display(pd.DataFrame(gt_beta))
print("Estimated beta:")
display(zip.parameters["marginal"]["mean"])
# Out:
# Ground Truth beta:
#          0         1         2         3         4         5         6   \
# 0 -0.150167  0.685220 -0.859776  0.597546 -0.601978 -1.405371 -0.462970
# 1 -0.002838  0.277729  0.705973  0.012628  0.153527  0.228416  1.488283
#
#          7         8         9         10        11        12        13  \
# 0 -0.840594  1.023071  2.364100  0.887982 -0.088155 -1.718876 -0.529043
# 1 -0.256917  0.574873  1.035424 -1.709142 -0.869144  0.070464 -1.061988
#
#          14        15        16        17        18        19
# 0  0.840888 -0.867252  0.757047 -1.363454  0.736631  0.802076
# 1  1.121783  0.945297  0.128713 -2.026952  2.685862  0.048394
# Estimated beta:
#                   0         1         2         3         4         5  \
# beta_dim0 -0.095837  0.379199 -0.555509  0.361461 -0.356368 -1.088415
# beta_dim1  0.040835  0.170326  0.496324  0.070374  0.111671  0.173326
#
#                  6         7         8         9        10        11  \
# beta_dim0 -0.36287 -0.562417  0.772251  2.035354  0.757255 -0.039712
# beta_dim1  1.18906 -0.142083  0.387929  0.882218 -1.411909 -0.567977
#
#                  12        13        14        15        16        17  \
# beta_dim0 -1.340264 -0.310329  0.708813 -0.668108  0.516734 -1.143283
# beta_dim1  0.023185 -0.708231  0.886017  0.725740  0.118139 -1.715088
#
#                 18        19
# beta_dim0  0.62334  0.537594
# beta_dim1  2.37047  0.029993

# %%
print("Ground Truth pi:")
display(pd.DataFrame(gt_pi))
print("Estimated pi:")
display(zip.parameters["marginal"]["mean"])
# Out:
# Ground Truth pi:
#          0         1         2         3         4         5         6   \
# 0  0.573209  0.020054  0.011407  0.269737 -0.799214  0.796565  0.421429
# 1  0.605469 -0.496005 -0.523467  0.448758  0.159527 -0.701970 -1.796181
# 2 -0.657959 -0.303333  0.381705 -1.197538  1.097517 -1.161555  0.805371
#
#          7         8         9         10        11        12        13  \
# 0 -0.127687 -0.743012 -0.324304  0.406883 -1.319917  0.508769 -0.095122
# 1  1.436443  1.557616 -1.423276  0.129916 -0.121867  0.410736 -0.105792
# 2  0.577190 -0.437968  0.213513 -1.132120 -0.080265  0.271150  0.177173
#
#          14        15        16        17        18        19
# 0  0.247867 -0.410273  0.642726  0.686417  0.333370 -0.719879
# 1  1.410649 -0.571888 -2.210049 -0.077659 -0.084773  0.750846
# 2  0.686795 -1.918524  0.317510 -0.127035  1.082386  1.368779
# Estimated pi:
#                   0         1         2         3         4         5  \
# beta_dim0 -0.095837  0.379199 -0.555509  0.361461 -0.356368 -1.088415
# beta_dim1  0.040835  0.170326  0.496324  0.070374  0.111671  0.173326
#
#                  6         7         8         9        10        11  \
# beta_dim0 -0.36287 -0.562417  0.772251  2.035354  0.757255 -0.039712
# beta_dim1  1.18906 -0.142083  0.387929  0.882218 -1.411909 -0.567977
#
#                  12        13        14        15        16        17  \
# beta_dim0 -1.340264 -0.310329  0.708813 -0.668108  0.516734 -1.143283
# beta_dim1  0.023185 -0.708231  0.886017  0.725740  0.118139 -1.715088
#
#                 18        19
# beta_dim0  0.62334  0.537594
# beta_dim1  2.37047  0.029993

# %% [markdown]
# Some of the pi's are not well estimated.

# %% [markdown]
# # Single cell example

# %% [markdown]
# Here I also show an example of fitting ZI-Poisson on real single cell data.

# %%
from scdiagnostics import compare_umap
import altair
altair.renderers.enable('png')
# Out:
# RendererRegistry.enable('png')

# %%
formula = {"mean_formula": "~ bs(pseudotime, degree=5)",
           "zero_inflation_formula": "~ bs(pseudotime, degree=5)"}
p = ZeroInflatedPoissonCopula(**formula)
p.fit(example_sce)
# Out:
# Epoch 70/500, Loss: 2.2851, Val Loss: 2.2912
# Estimating copula correlation: 100%|██████████| 3/3 [00:00<00:00, 14.38it/s]

# %%
samples = p.sample(example_sce.obs)
compare_umap(example_sce, samples, color="pseudotime")
# Out:
# alt.FacetChart(...)

# %% [markdown]
# # Notes

# %% [markdown]
# I think we can create a general function for reformatting the formula input (currently now it’s defined separately in the negbin estimator file, but other files can also benefit from it).
#
# It would also be nice if the model.param keys and the keys of dictionary used to calculate the likelihood are consistent and if people can retrieve the model matrix from the model. it will also help the calculation of AIC/BIC.
