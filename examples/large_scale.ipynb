# %%
import anndata
from scdesigner.simulator import scdesigner
from scdesigner.margins.marginal import NB

# %%
save_path = "data/200120_10x.h5ad"
example_sce = anndata.read_h5ad(save_path, backed=True)
example_sce

# %%
from scdesigner.simulator import scdesigner
from scdesigner.margins.marginal import NB

sim = scdesigner(example_sce, NB("~ batch", batch_size=int(1e3)), multivariate=None, max_epochs=1, chunk_size=int(5e3))
